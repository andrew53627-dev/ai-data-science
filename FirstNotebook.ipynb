# %% [markdown]
# <a href="https://colab.research.google.com/github/andrew53627-dev/ai-data-science/blob/main/FirstNotebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Ask the student to enter their name.

# %%
name = input("What is your name? ")
# Out:
# What is your name? Andrew

# %%
scores = [85,90,95]

# %%
average = sum(scores) / len(scores)

# %%
print("Hello, ", name)
print("Your average score is: ", average)
# Out:
# Hello,  Andrew
# Your average score is:  90.0
